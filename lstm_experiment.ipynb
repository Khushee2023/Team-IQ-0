# %% [markdown]
# # LSTM Experiment
#
# This notebook is a lightweight launcher for Arihanta's MSCAD LSTM pipeline. Run the training script from the project root for the full reproducible workflow.

# %%
# %run ../src/train_lstm.py
